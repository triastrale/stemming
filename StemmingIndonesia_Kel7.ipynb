# %% [markdown]
# <a href="https://colab.research.google.com/github/triastrale/stemming/blob/nazief_adriani/StemmingIndonesia_Kel7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
from itertools import combinations

# %%
# Baca dataset
df = pd.read_csv('Dataset_BINDO - Sheet1.csv')
df
# Out:
#                                                 judul  \
# 0   4 Calon Kuat Penerus Paus Fransiskus, Ada dari...
# 1   AS Soro QRIS & GPN dalam Negosiasi Dagang, Ini...
# 2   Dampak Tarif Resiprokal Trump terhadap Industr...
# 3   Dilema Persalinan Caesar di Era JKN: Antara Ha...
# 4   Dugaan Ekspoitasi Mantan Pemain Sirkus, Komisi...
# 5                     Eksistensi Media Massa Nasional
# 6                   Global South dan Ilusi Netralitas
# 7   Gonjang-ganjing Isu Evakuasi Warga Gaza ke Ind...
# 8   Makna Kebersamaan dalam Tradisi Mengibung dan ...
# 9   Peran Bimbingan dan Konseling Dalam Pendidikan...
# 10  Senarai Catatan di Hari Buku Sedunia dan Tanta...
# 11  Bagaimana mengubah ‘eco-anxiety’ kita menjadi ...
# 12  Benarkah anak-anak butuh mata pelajaran koding...
# 13  Kecanduan media sosial bikin anak muda rentan ...
# 14  Ini 5 Bahaya Makanan Junk Food yang Perlu Diwa...
# 15  Ketika Jas Putih Menjadi Tameng: Menggugat Sis...
# 16        Rupiah di Tengah Perekonomian yang Tertekan
# 17                       Okupasi Senyap Ruang Angkasa
# 18  Pendidikan Dasar dan Menengah yang Bermutu unt...
# 19  Teknologi Dirgantara Untuk Operasi Bantuan Kem...
# 20  China Akan Balas Negara-negara yang Bekerja Sa...
# 21        Rupiah di Tengah Perekonomian yang Tertekan
# 22                       Korupsi yang Menjegal Daerah
# 23              Melanjutkan Cita-cita Politik Kartini
# 24                 Merawat Kartini di Kebun Nirkertas
# 25     Peran Media Massa dalam Membentuk Opini Publik
# 26  Ragam Keluhan Mitra MBG: Menalangi Biaya hingg...
# 27                            Robot Ikut Lomba Lari\r
# 28                    TKDN dan Negosiasi Dagang RI-AS
# 29  Untuk Bantu Pahami Matematika, Anak Perlu Meto...
#
#                                                   isi
# 0   Jakarta, CNN Indonesia -- Kepergian mendiang P...
# 1   Jakarta, CNBC Indonesia - Penggunaan sistem pe...
# 2   TEMPO.CO, Jakarta - Ekonom dari Ins tute for D...
# 3   Beredarnya narasi bahwa operasi caesar tidak a...
# 4   Komisi III DPR mengundang sejumlah mantan pema...
# 5   Berbicara tentang media arus utama (mainstream...
# 6   Mereka, para negara peserta Konferensi Asia-Af...
# 7   Presiden RI Prabowo Subianto pada pekan kedua ...
# 8   Tradisi Megibung dari Bali dan Kembul Bujana d...
# 9   WEBINAR HUT ABKIN ke-49 II PD ABKIN JAWA TENGA...
# 10  Tanggal ini dipilih sebagai penghormatan kepad...
# 11  Perubahan iklim hingga bencana alam yang terja...
# 12  Februari 2025 lalu, Badan Standar, Kurikulum, ...
# 13  Kamu mungkin terbiasa menghabiskan waktu berja...
# 14  Halodoc, Jakarta –  Junk food alias makanan ce...
# 15  Beberapa waktu lalu, publik dikejutkan oleh pe...
# 16  Nilai tukar rupiah terus mengalami tekanan cuk...
# 17  Tanpa adanya rezim internasional yang kuat dan...
# 18  Menteri Pendidikan Dasar dan Menengah Abdul Mu...
# 19  Dinamika global terus bergerak diwarnai ketega...
# 20  China memperingatkan akan membalas negara-nega...
# 21  Nilai tukar rupiah terus mengalami tekanan cuk...
# 22  Kejaksaan Tinggi Banten menahan Kepala Dinas L...
# 23  Melanjutkan Cita-cita Politik Kartini\n\nKarti...
# 24  “Saya mau bekerja bukan karena ingin menjadi b...
# 25  Media massa memiliki peran yang sangat penting...
# 26  Sebagian mitra Makan bergizi Gratis mengeluhka...
# 27  Lomba lari setengah maraton di Beijing yang di...
# 28  Beberapa asosiasi usaha dan pengamat mengkhawa...
# 29  Kementerian Komunikasi dan Informatika (Kominf...

# %%
# List imbuhan dan akhiran
IMBUHAN = ['peng', 'pem', 'peny', 'per','pen', 'ber', 'meny', 'meng', 'mem', 'men', 'me', 'ter', 'nya', 'se','an', 'ku', 'mu', 'kan']
AKHIRAN = ['an', 'nya', 'ku', 'mu', 'kan']

# Fungsi untuk stemming satu teks
def clean_text(text):
    if pd.isna(text):  # Kalau kosong, langsung return kosong
        return ''
    clean_words = []
    new_string = re.sub(r'[^\w\s]', '', text)  # Hapus tanda baca
    words = new_string.split()

    for w in words:
        clean_word = w.lower()

        # Bersihkan imbuhan awal
        for imbuh in IMBUHAN:
            if re.match(imbuh, clean_word):
                clean_word = re.sub(f"^{imbuh}", '', clean_word)

        # Bersihkan akhiran
        for akhir in AKHIRAN:
            clean_word = re.sub(f"{akhir}$", '', clean_word)

        clean_words.append(clean_word)

    return " ".join(clean_words)

# Terapkan fungsi ke kolom 'isi'
df['isi_clean'] = df['isi'].apply(clean_text)
df['isi_clean']
# Out:
# 0     jakarta cnn indonesia kepergi diang paus frans...
# 1     jakarta cnbc indonesia guna sistem bayar indon...
# 2     tempoco jakarta ekonom dari ins tute for devel...
# 3     edar narasi bahwa operasi caesar tidak ak dita...
# 4     komisi iii dpr undang jumlah mant ain sirkus o...
# 5     bicara tentang dia arus utama mainstream hari ...
# 6     reka para negara peserta konferensi asiaafrika...
# 7     presiden ri prabowo subianto pada pek kedua ap...
# 8     tradisi gibung dari bali d kembul bujana dari ...
# 9     webinar hut abkin ke49 ii pd abkin jawa tengah...
# 10    tanggal ini dipilih bagai hormat kepada dua sa...
# 11    ubah iklim hingga bencana alam yang jadi di ma...
# 12    februari 2025 lalu bad standar rikulum d asesm...
# 13    ka ngkin biasa habisk waktu jamjam lancar di d...
# 14    halodoc jakarta junk food alias ma cepat saji ...
# 15    beberapa waktu lalu publik dikejutk oleh ita t...
# 16    nilai tukar rupiah us alami te cukup at bebera...
# 17    tanpa ada rezim internasional yang at d dapat ...
# 18    i didik dasar d engah abdul ti dalam rapat ker...
# 19    dinamika global us gerak diwarnai ketegang pol...
# 20    china peringatk ak balas negaranegara yang bek...
# 21    nilai tukar rupiah us alami te cukup at bebera...
# 22    kejaksa tinggi banten ah kepala dinas lingkung...
# 23    lanjutk citacita politik kartini kartini tidak...
# 24    saya mau bekerja buk karena ingin jadi besar a...
# 25    dia massa iliki  yang sangat ting dalam bentuk...
# 26    bagi mitra mak gizi gratis eluhk tidak dapat b...
# 27    lomba lari tengah maraton di beijing yang diik...
# 28    beberapa asosiasi usaha d amat khawatirk relak...
# 29    kementeri komunikasi d informatika kominfo ril...
# Name: isi_clean, dtype: object

# %%
#Tokenizing
def tokenizing(input):
  input = input.replace(".", "")
  input = input.replace(",", "")
  input = input.replace(":", "")
  input = input.replace("-", " ")
  input = input.replace("?", "")
  input = input.replace("!", "")
  input = input.replace("(", "")
  input = input.replace(")", "")
  input = input.replace("[", "")
  input = input.replace("]", "")
  input = input.replace("{", "")
  input = input.replace("}", "")
  input = input.replace("'", "")
  input = input.replace('"', "")
  input = input.replace("/", "")
  return input

# %%
#Pemisahan kata berdasarkan spasi
def split_words(words):
  return words.split(' ')

# %%
#Stopwords
# open stopword

def stop_word(word):

  f = open('id.stopwords.02.01.2016.txt')
  s_word = f.read()

  if word not in s_word :
    return word


  f.close()

# %%
#Kamus
kamus_clean = []

with open('kata-dasar-indonesia.txt') as f:
  kamus = f.read()
  kamus = kamus.split(' ')

  for w in kamus:

    rx = re.findall(r'[^\n]+$', w)

    kamus_clean.append(rx[0])

AKAR_KATA = []

def kamus_word(word='tes'):

    # kamus = map(clean_word, kamus)
    if word in kamus_clean:
      AKAR_KATA.append(word)
      return None
    return word

# %%
#Hapus Infleksional Suffix
def hapus_infleksional_suffiks(word):
  # akhiran -lah, -kah, -nya, -tah, -pun
  if word.endswith('lah') or word.endswith('kah') or word.endswith('nya') or word.endswith('tah') or word.endswith('pun'):
    word = word[0 : len(word) - 3]

    # check if word exist in kamus
    word_check = kamus_word(word)

    return word_check

  # akhiran -ku, -mu
  elif word.endswith('ku') or word.endswith('mu'):
    word = word[0 : len(word) - 2]

    # check if word exist in kamus
    word_check = kamus_word(word)
    return word_check

  return word

# %%
#Hapus derivation suffixes

def hapus_derivation_suffiks(word):
    # akhiran kan
  if word.endswith('kan'):
    word = word[0 : len(word) - 3]

    # check if word exist in kamus
    word_check = kamus_word(word)
    return word_check

  # akhiran i
  if word.endswith('i'):
    word = word[0 : len(word) - 1]

    # check if word exist in kamus
    word_check = kamus_word(word)
    return word_check

  # akhiran an
  if word.endswith('an'):
    word = word[0 : len(word) - 2]

    # check if word exist in kamus
    word_check = kamus_word(word)
    return word_check


  return word

# %%
#Hapus derivation prefiks

def hapus_derivation_prefiks(word):
  # awalan mempel-
  if (word.startswith('mempel')) and (len(word) > 6):
    sub_word = word[6:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check

    return word_check

  # awalan memper-
  if (word.startswith('memper')) and (len(word) > 6):
    sub_word = word[6:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:

      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check

    return word_check

  # awalan diper-, keber-, keter-
  if (word.startswith('diper') or word.startswith('keber') or word.startswith('keter')) and (len(word) > 5):
    sub_word = word[5:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:

      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check
    return word_check

  # awalan meng-, peng-
  if (word.startswith('meng') or word.startswith('peng')) and (len(word) > 4):
    sub_word = word[4:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)
      # check word again in kamus
      word_check = kamus_word(word_pref_suff)

      if word_check != None:
        # add 'k' in front word
        sub_word = 'k' + word_check

        # check word again in kamus
        word_check = kamus_word(sub_word)

        if word_check != None:
          # check word in derivation suffiks
          word_pref_suff_k = hapus_derivation_suffiks(word_check)

          # check word again in kamus after add k in front
          word_check = kamus_word(word_pref_suff_k)
          return word_check

    return word_check

  # awalan meny-, peny-
  if (word.startswith('meny') or word.startswith('peny')) and (len(word) > 4):
    sub_word = word[4:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      if word_check != None:

        # add 's' in front word
        sub_word = 's' + word_check

        # check word again in kamus
        word_check = kamus_word(sub_word)
        if word_check != None:
          # check word in derivation suffiks
          word_pref_suff_s = hapus_derivation_suffiks(word_check)

          # check word again in kamus after add s in front
          word_check = kamus_word(word_pref_suff_s)
          return word_check
    return word_check

  # awalan mel-, mer-, pel-, per-
  if (word.startswith('mel') or word.startswith('mer') or word.startswith('pel') or word.startswith('per')) and (len(word) > 3):
    sub_word = word[3:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check
    return word_check

  # awalan men-, pen-
  if (word.startswith('men') or word.startswith('pen')) and (len(word) > 3):
    sub_word = word[3:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      if word_check != None:
        # add 's' in front word
        sub_word = 't' + word_check

        # check word again in kamus
        word_check = kamus_word(sub_word)

        if word_check != None:
          # check word in derivation suffiks
          word_pref_suff_t = hapus_derivation_suffiks(word_check)

          # check word again in kamus after add s in front
          word_check = kamus_word(word_pref_suff_t)
          return word_check
    return word_check


  # awalan mem-, pem-
  if (word.startswith('mem') or word.startswith('pem')) and (len(word) > 3):
    sub_word = word[3:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      if word_check != None:
        # add 's' in front word
        sub_word = 'p' + word_check

        # check word again in kamus
        word_check = kamus_word(sub_word)

        if word_check != None:
          # check word in derivation suffiks
          word_pref_suff_p = hapus_derivation_suffiks(word_check)

          # check word again in kamus after add s in front
          word_check = kamus_word(word_pref_suff_p)
          return word_check
    return word_check
  # awalan bel-, ber-, tel-, ter-
  if (word.startswith('bel') or word.startswith('ber') or word.startswith('tel') or word.startswith('ter')) and (len(word) > 3):
    sub_word = word[3:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check

    return word_check

  # tipe awalan ke 1 : di-, ke-, se-
  if (word.startswith('di') or word.startswith('ke') or word.startswith('se')) and (len(word) > 2):
    sub_word = word[2:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check
    return word_check


  # tipe awalan ke 2 : be-, te-
  if (word.startswith('be') or word.startswith('te')) and (len(word) > 2):
    sub_word = word[2:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)
    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check

    return word_check

  # tipe awalan ke 3 : me-, pe-
  if (word.startswith('me') or word.startswith('pe')) and (len(word) > 2):
    sub_word = word[2:]
    # check if word exist in kamus
    word_check = kamus_word(sub_word)

    if word_check != None:
      # check word in derivation suffiks
      word_pref_suff = hapus_derivation_suffiks(word_check)

      # check word again in kamus
      word_check = kamus_word(word_pref_suff)
      return word_check

    return word_check

# %%
with open('Dataset_BINDO - Sheet1.csv') as f:
  words = f.read()
  # print(f'jumlah kata awal : {len(words)}')

  # lower words
  words = words.lower()

  # tokenizing
  words = tokenizing(words)
  # print(f'jumlah kata setelah tokenizing : {len(words)}')

  # split words
  words = words.split(' ')
  print(f'jumlah kata awal : {len(words)}')


  list_stop_words = []
  # stop word
  for w in words:
    word = stop_word(w)
    if word != None:
      list_stop_words.append(word)

  print(f'jumlah kata setelah stop word : {len(list_stop_words)}')

  list_not_in_kamus_words = []
  # kamus word
  for w in list_stop_words:
    word = kamus_word(w)
    if word != None:
      list_not_in_kamus_words.append(word)

  print(f'jumlah kata setelah kamus : {len(list_not_in_kamus_words)}')
  print(f'Akar kata {len(AKAR_KATA)}')

  # hapus infleksional suffiks
  list_not_infleksional_suffiks = []

  for w in list_not_in_kamus_words:
    word = hapus_infleksional_suffiks(w)
    if word != None:
      list_not_infleksional_suffiks.append(word)

  print(f'jumlah kata setelah infleksional suffiks : {len(list_not_infleksional_suffiks)}')
  print(f'Akar kata {len(AKAR_KATA)}')

  # hapus derivation suffiks
  list_not_derivation_suffiks = []

  for w in list_not_infleksional_suffiks:
    word = hapus_derivation_suffiks(w)
    if word != None:
      list_not_derivation_suffiks.append(word)

  print(f'jumlah kata setelah derivation suffiks : {len(list_not_derivation_suffiks)}')
  print(f'Akar kata {len(AKAR_KATA)}')

  # hapus derivation prefix
  list_not_in_kamus = []

  for w in list_not_derivation_suffiks:
    word = hapus_derivation_prefiks(w)
    if word != None:
      list_not_in_kamus.append(word)

  print(f'jumlah kata setelah derivation prefiks : {len(list_not_in_kamus)}')
  print(f'Akar kata {len(AKAR_KATA)}')

  print(f'Kata yang tak ada di kamus {list_not_in_kamus}')
# Out:
# jumlah kata awal : 22029
# jumlah kata setelah stop word : 12757
# jumlah kata setelah kamus : 7191
# Akar kata 5566
# jumlah kata setelah infleksional suffiks : 7057
# Akar kata 5700
# jumlah kata setelah derivation suffiks : 6587
# Akar kata 6170
# jumlah kata setelah derivation prefiks : 1008
# Akar kata 9281
# Kata yang tak ada di kamus ['nin', 'puncul', 'lanjutnya\nsejum', 'potens', 'jarah\n\nkardinal', 'evisi\n\nbah', 'kerja\n\nedward', 'kgantikannya\n\nkardinal', 'kaster', 'egraph\n\nnamun', 'hat', 'pemimpin', 'tasihat', 'tasihat', 'pilih\n\nkardinal', 'sebut\n\npaus', 'nediktus', 'tasihat', 'ebut', 'ketahu', 'tila', 'tingg', 'ring\n\npeter', 'kgant', 'tila', 'pemimpin', 'caya', 'ttin\n\nsecara', 'kristen', 'sebut\n\nnamun', 'pilik', 'kungsi\n\nerdo', 'jal', 'kgant', 'posis', 'salahan\n\nnamun', 'ug', 'tdonca', 'kgant', 'tdidikan\n\ndar', 'pilik', 'tingg', 'pilik', 'kgant', 'tola', 'koordinas', 'ob', 'onggar', 'ob', 'prediks', 'kecual', 'tila', 'khawa', 'osot', 'tenagakerja', 'prediks', 'tila', 'ebih', 'potens', 'la', 'potens', 'puncul', 'teliti\nkesehat', 'tila', 'panfaat', 'sehatan\n\nsejak', 'uncur', 'dis\n\nnamun', 'puncul', 'ring\nkal', 'la', 'tentuan\nd', 'rasa\nterbaik', 'mestinya\ntetap', 'dis\n\nsecara', 'rius\nsepert', 'ni\nnamun', 'ebih', 'cara\nsignifikan\n\nd', 'pendid', 'pilik', 'indikas', 'dishield', 'lukan\n\npenulis', 'dis”', 'rap\nmenjad', 'pahami\nhak', 'besar\nd', 'onjak', 'kadar\nperkara', 'hatikan\nkeberlanjut', 'kait\npersalin', 'bagai\npilih', 'salinan\nnormal', 'operas', 'naga\nmedis', 'hingga\nmemicu', 'simpangsiur', 'seimbang', 'pangku\nkepentingan—pemerin', 'serta—perlu', 'sinerg', 'eksploitas', 'nin', 'partisipas', 'komunikas', 'nin', 'eksploitas', 'tindaklanjut', 'buda', 'pilik', 'pekerja', 'buda', 'tdid', 'koordinas', 'menterianlembaga', 'tindaklanjut', 'atih', 'pb', 'keksploitas', 'dsos', 'ampau', 'osot', 'amping', 'tdasar\nada', 'garisbawah', 'dsos', 'kambilalih', 'aih', 'embaga', 'operas', 'kesamping', 'dsos', 'kesamping', 'dsos', 'bencian\ndalam', 'kantisipas', 'dsos', 'karakter', 'dsos', 'embaga', 'dsos', 'dsos', 'dsos\nproteks', 'mest', 'dsos', 'law', 'dsos', 'adab\nmempertah', 'pilik', 'sesua', 'limpahruah', 'laya', 'dsos', 'mest', 'dsos', 'law', 'dsos', 'mest', 'panfaat', 'la', 'hat\n\nglobal', 'dir', 'be', 'kuasaan\n\nnamun', 'tahan\n\nkapitalisme', 'emah;', 'sesua', 'pilik', 'pilik', 'operas', 'am\n\nkita', 'piha', 'piha', 'saat\n\ndalam', 't', 'tambangan\n\nd', 'uncur', 'uas', 'ksiko', 'tawar;', 'encana', 'orientas', 'anjut', 'piha', 'tcar', 'seimbang', 'umus', 'pilik', 'anggeng', 'padai;', 'tegosias', 'tcar', 'tcar', 'hent', 'apresias', 'belumnya\n\nin', 'pemimpin', 'terimanya\n\npresiden', 'elokas', 'ngah”', 'nant', 'terimanya\n\nas', 'sebut\n\nwitkoff', 'unding', 'sebut\n\nnamun', 'tola', 'sebut\n\nmesk', 'kgelinding\n\nadu', 'tola', 'adops', 'perangkap', 'eka\n\nmaka', 'kevakuas', 'evakuas', 'lesai\n\nproses', 'kungs', 'caya', 'kevakuas', 'mbul', 'janatradis', 'gibung', 'mbul', 'kedar', 'bag', 'gibung', 'tut', 'gibung', 'ang\n\n\ntradis', 'setara', 'gibung', 'luarga\n\n\nkata', 'gibung', 'bag', 'samaan\n\n\natur', 'gibung', 'ekat', 'mbul', 'mbul', 'aya', 'iput', 'mbul', 'tikmat', 'bag', 'pilik', 'tdalam\n\n\nsejarah', 'mbul', 'caya', 'gibung', 'mbul', 'bag', 'bag', 'gibung', 'mbul', 'sederhanaan\n\n\nd', 'gibung', 'mbul', 'pudar\n\n\nkekhawatir', 'gibung', 'mbul', 'sajiannya\n\n\nwury', 'perhat', 'gibung', 'mbul', 'estar', 'gibung', 'mbul', 'gibung', 'mbul', 'ahir', 'gibung', 'mbul', 'har', 'tdid', 'kert', 'tdid', 'pilik', 'tdid', 'tdid', 'pilik', 'pilik', 'ketahu', 'pbentu', 'pilik', 'fungs', 'ampil', 'interaks', 'tdid', 'perintah\n\n\npendid', 'tdid', 'tdid', 'tidakmerata', 'tdid', 'perintah\n\n\nmenanggap', 'tdid', 'mendikdasmen', 'tdid', 'fungs', 'kontribus', 'karakter', 'siplintanggung', 'rasetika', 'ampil', 'tdeteks', 'nangnyam', 'pbully', 'undung', 'tunju', 'tdid', 'tdid', 'ibat', 'hargai\nsenara', 'adops', 'ketahu', 'w', 'nsorik', 'kadops', 'tdidikan\npemerin', 'gital\n\n\nkecenderung', 'oritik', 'pbelajar', 'pudah', 'konsentras', 'telit', 'mdikbud', 'oritis', 'iput', 'adaptas', 'pbaca\nprogram', 'tdid', 'pbelajar', 'tdalam\nmesk', 'tdid', 'ketahu', 'adaban\nbagaimana', 'pilik', 'eka\nlalu', 'konsums', 'is', 'simistis\nuntuk', 'is', 'estar', 'pilik', 'hubungan\n3', 'partisipas ...

# %%
print(AKAR_KATA)
print(len(AKAR_KATA))
# Out:
# ['calon', 'kuat', 'paus', 'tetangga', 'mendiang', 'paus', 'umat', 'dunia', 'nama', 'kardinal', 'calon', 'kuat', 'paus', 'nama', 'sejarah', 'paus', 'kawasan', 'nama', 'kardinal', 'gadang', 'kuat', 'paus', 'umat', 'kandidat', 'bursa', 'paus', 'pria', 'paus', 'populer', 'kaum', 'progresif', 'gereja', 'hangat', 'progresif', 'mendiang', 'paus', 'reformis', 'mendiang', 'paus', 'tinggal', 'seminari', 'kamar', 'uskup', 'mobil', 'bus', 'pakar', 'buku', 'kardinal', 'favorit', 'paus', 'kepala', 'gereja', 'kandidat', 'kuat', 'muda', 'paus', 'kardinal', 'cenderung', 'hati', 'paus', 'relatif', 'muda', 'paus', 'relatif', 'muda', 'kardinal', 'kunci', 'paus', 'isu', 'isu', 'iklim', 'sosial', 'kardinal', 'calon', 'kuat', 'umat', 'dunia', 'sejarah', 'paus', 'kulit', 'hitam', 'uskup', 'agung', 'cape', 'paus', 'kardinal', 'sejarah', 'negara', 'kepala', 'dewan', 'lembaga', 'sosial', 'asasi', 'manusia', 'paus', 'isu', 'isu', 'iklim', 'luas', 'konferensi', 'internasional', 'forum', 'ekonomi', 'paus', 'departemen', 'kardinal', 'kantor', 'langkah', 'departemen', 'pengaruh', 'kardinal', 'akademi', 'bidang', 'ilmu', 'ilmu', 'wawancara', 'paus', 'gereja', 'tampil', 'media', 'konservatif', 'muncul', 'nama', 'kardinal', 'uskup', 'agung', 'calon', 'kuat', 'paus', 'kandidat', 'kuat', 'konservatif', 'gereja', 'kardinal', 'ahli', 'hukum', 'kanon', 'dab', 'mahir', 'hukum', 'umat', 'gereja', 'kondisi', 'hukum', 'gerejawi', 'paus', 'sosok', 'teologis', 'konservatif', 'akar', 'benua', 'pragmatis', 'paus', 'rohaniwan', 'krisis', 'migran', 'paus', 'gereja', 'gereja', 'bentuk', 'manusia', 'nasionalis', 'perdana', 'menteri', 'negara', 'perdana', 'menteri', 'kandidat', 'perang', 'netral', 'dialog', 'imam', 'serikat', 'buku', 'diplomat', 'kompeten', 'otak', 'diplomasi', 'internasional', 'paus', 'akibat', 'skandal', 'properti', 'gedung', 'bekas', 'kompeten', 'proses', 'pastor', 'kardinal', 'nama', 'nama', 'cocok', 'umat', 'muncul', 'kandidat', 'kuat', 'paus', 'kaum', 'progresif', 'gereja', 'kardinal', 'pulau', 'paus', 'kepala', 'departemen', 'budaya', 'muncul', 'nama', 'kardinal', 'uskup', 'agung', 'calon', 'kuat', 'paus', 'sosok', 'progresif', 'paus', 'kawasan', 'kardinal', 'sekretaris', 'jenderal', 'sinode', 'uskup', 'posisi', 'gereja', 'paus', 'konservatif', 'kandidat', 'kompromi', 'nama', 'kardinal', 'gadang', 'kandidat', 'kuat', 'paus', 'ideologi', 'gender', 'radikalisme', 'negosiasi', 'dagang', 'sistem', 'gerbang', 'nasional', 'negosiasi', 'serikat', 'koordinator', 'bidang', 'bank', 'otoritas', 'jasa', 'konferensi', 'tarif', 'kartu', 'bank', 'perihal', 'wajib', 'silam', 'lokal', 'bisnis', 'sistem', 'transaksi', 'kartu', 'lokal', 'sumber', 'lobi', 'negara', 'alat', 'lokal', 'tulis', 'media', 'email', 'detail', 'email', 'halaman', 'informasi', 'via', 'surat', 'elektronik', 'email', 'dagang', 'laos', 'gana', 'transaksi', 'mayoritas', 'investor', 'transaksi', 'partner', 'lokal', 'transaksi', 'nasabah', 'laba', 'kartu', 'kredit', 'fasilitas', 'fasilitas', 'tarif', 'bea', 'produk', 'ekspor', 'fasilitas', 'tarif', 'resiprokal', 'industri', 'ekonom', 'hasan', 'dampak', 'tarif', 'resiprokal', 'serikat', 'rela', 'moderat', 'sisi', 'diskusi', 'publik', 'genderang', 'perang', 'komoditas', 'ekspor', 'tarif', 'resiprokal', 'produk', 'ekspor', 'teks', 'garmen', 'alas', 'kaki', 'sawit', 'dampak', 'industri', 'teks', 'produsen', 'serat', 'benang', 'teks', 'sisi', 'buruh', 'teks', 'konveksi', 'pabrik', 'industri', 'unit', 'tenaga', 'ribu', 'negara', 'ringan', 'level', 'tarif', 'serikat', 'posisi', 'mitra', 'dagang', 'persen', 'total', 'ekspor', 'pasar', 'negara', 'produk', 'tanah', 'surplus', 'signifikan', 'miliar', 'dolar', 'surplus', 'nilai', 'ekspor', 'nilai', 'negara', 'cenderung', 'kondisi', 'presiden', 'serikat', 'tarif', 'impor', 'tarif', 'impor', 'minimum', 'negara', 'dunia', 'langkah', 'industri', 'produk', 'negara', 'negara', 'dampak', 'tarif', 'persen', 'negara', 'daya', 'saing', 'produk', 'ekspor', 'pasar', 'negara', 'tarif', 'tarif', 'tarif', 'produk', 'ekspor', 'bentuk' ...
# 9281

# %%
# ========== EVALUASI ==========
from collections import defaultdict
import numpy as np

# Mean Word Count
df['word_count'] = df['isi_clean'].apply(lambda x: len(x.split()))
mean_word_count = df['word_count'].mean()
print(f'\nMean Word Count: {mean_word_count:.2f}')

# Understemming Index
total_kata = len(words)
understemmed = len(list_not_in_kamus)
understemming_index = understemmed / total_kata
print(f'Understemming Index: {understemming_index:.4f}')

# Overstemming Index
akar_dict = defaultdict(int)
for w in AKAR_KATA:
    akar_dict[w] += 1

overstemmed = sum([v - 1 for v in akar_dict.values() if v > 1])
overstemming_index = overstemmed / len(AKAR_KATA) if len(AKAR_KATA) else 0
print(f'Overstemming Index: {overstemming_index:.4f}')
# Out:
# Mean Word Count: 740.83
# Understemming Index: 0.0458
# Overstemming Index: 0.8752
